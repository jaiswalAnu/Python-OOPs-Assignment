# %% [markdown]
# ##Python OOPs Assignment Questions

# %% [markdown]
# # Theoretical question

# %% [markdown]
#  # 1. What is Object-Oriented Programming (OOP)?
#   - OOP is a programming style based on using objects, which combine data (attributes) and behaviors (methods), to model real-world scenarios. It focuses on principles like inheritance, encapsulation, abstraction, and polymorphism.
#
# ---

# %% [markdown]
# #2. What is a class in OOP?
#   - A class is a blueprint for creating objects. It defines the structure and behavior (methods) that objects created from it will have.
#
# ```python
# class Animal:
#     def __init__(self, name):
#         self.name = name
# ```
#
#
# ---

# %% [markdown]
# #3. What is an object in OOP?
#   - An object is an instance of a class that contains specific data and behavior based on the class definition.
#
#
# ```python
# dog = Animal("Dog")
# print(dog.name)
#  # Output: Dog
# ```
#
#
#
# ---

# %% [markdown]
# #4. What is the difference between abstraction and encapsulation?
#
#   - Abstraction hides the internal workings and shows only the necessary details.
#   - Encapsulation restricts direct access to data by bundling it with methods for controlled access.
#
# ---

# %% [markdown]
# # 5. What are dunder methods in Python?
#   - Dunder methods are special methods surrounded by double underscores (e.g., *__*init__, *__*str__) that let you define custom behavior for operators, object initialization, etc.
#
# Example:
#
#
# ```python
# class Number:
#     def __init__(self, value):
#         self.value = value
#
#     def __add__(self, other):
#         return self.value + other.value
# ```
#
#
# ---

# %% [markdown]
# #6. Explain the concept of inheritance in OOP.
#   - Inheritance allows a class to reuse the properties and methods of another class. The derived (child) class can also extend or modify the parent class behavior.
#
# Example:
#
#
# ```python
# class Vehicle:
#     def move(self):
#         return "Moving..."
#
# class Car(Vehicle):
#     def move(self):
#         return "Driving..."
#
# ```
#
#
# ---

# %% [markdown]
# #7. What is polymorphism in OOP?
#   - Polymorphism lets different classes provide their own version of the same method. This is useful for handling objects from different classes using the same interface.
#
# Example:
#
#
#
#
# ```python
# class Dog:
#     def speak(self):
#         return "Bark"
#
# class Cat:
#     def speak(self):
#         return "Meow"
#
# ```
#
#
#
# ---

# %% [markdown]
# #8. How is encapsulation achieved in Python?
#   - Encapsulation is achieved by making attributes private using a double underscore (e.g., __attribute) and providing getter and setter methods to control access.
#
#
# ---

# %% [markdown]
# #9. What is a constructor in Python?
#   - A constructor is a special method (__init__) that runs automatically when an object is created. It initializes the object's attributes.
#
#
# ```python
# class Person:
#     def __init__(self, name):
#         self.name = name
#
# ```
#
#
# ---

# %% [markdown]
# #10. What are class and static methods in Python?
#
#   - Class Method: Operates on the class itself. Defined with @classmethod and takes cls as the first parameter.
#   - Static Method: Does not operate on an instance or class. Defined with @staticmethod.
#
#
# ```python
# class MyClass:
#     @classmethod
#     def class_method(cls):
#         return "This is a class method."
#
#     @staticmethod
#     def static_method():
#         return "This is a static method."
#
# ```
#
#
# ---

# %% [markdown]
# # 11. What is method overloading in Python?
#   - Method overloading is defining multiple methods with the same name but different parameters. Python does not support method overloading directly but can be mimicked using default arguments.
#
# ---

# %% [markdown]
# #12. What is method overriding in OOP?
# - Method overriding allows a child class to provide a specific implementation for a method that is already defined in its parent class. The overridden method must have the same name, parameters, and return type.
#
#
#
# ---

# %% [markdown]
# #13. What is a property decorator in Python?
# - The @property decorator is used to define getter methods for a property, making it accessible like an attribute. It is often combined with setters to control access and modifications to attributes.
#
#
# ```python
# class Person:
#     def __init__(self, name):
#         self._name = name
#
#     @property
#     def name(self):
#         return self._name
#
#     @name.setter
#     def name(self, value):
#         self._name = value
#
# ```
#
# ---

# %% [markdown]
# #14. Why is polymorphism important in OOP?
# - Polymorphism is important as it allows code to handle objects of different classes in a unified way, enhancing flexibility and extensibility. It supports dynamic method resolution at runtime.
#
# ---

# %% [markdown]
# #15. What is an abstract class in Python?
# - An abstract class is a class that cannot be instantiated and often contains one or more abstract methods. Abstract methods are defined using the @abstractmethod decorator and must be implemented by subclasses.
# ---

# %% [markdown]
# # 16. What are the advantages of OOP?
# - Encourages modular and reusable code.
# - Promotes better organization and maintainability.
# - Supports real-world modeling using objects, making programs intuitive.
# ---

# %% [markdown]
# #17. What is the difference between a class variable and an instance variable?
# - Class variable: Shared across all instances of the class.
# - Instance variable: Unique to each instance, defined using self.
# ---

# %% [markdown]
# #18. What is multiple inheritance in Python?
# - Multiple inheritance allows a class to inherit from more than one parent class.
# Example:
# ```python
# class A: pass
# class B: pass
# class C(A, B): pass
# ```
# ---

# %% [markdown]
# # 19. Explain the purpose of `__str__` and `__repr__` methods in Python.
# - `__str__`: Provides a user-friendly string representation of an object.
# -  `__repr__`: Provides a developer-friendly string representation, often used for debugging.
# ---

# %% [markdown]
# # 20. What is the significance of the super() function in Python?
# - The super() function allows a child class to call a method from its parent class, commonly used in method overriding to extend the parent class's behavior.
# ---

# %% [markdown]
# # 21. What is the significance of the `__del__` method in Python?
# - The `__del__` method is a destructor method called when an object is about to be destroyed. It is used for cleanup operations.
# ---

# %% [markdown]
# #22. What is the difference between @staticmethod and @classmethod in Python?
# - @staticmethod: Does not take self or cls and operates independently of the class or instance.
# - @classmethod: Takes cls as the first argument and operates on the class level.
# ---

# %% [markdown]
# # 23. How does polymorphism work in Python with inheritance?
# - In Python, polymorphism allows a parent class reference to execute child class methods. For example, Animal.speak() may behave differently for Dog and Cat.
#
# ---

# %% [markdown]
# #24. What is method chaining in Python OOP?
# - Method chaining allows multiple method calls on the same object in a single statement by returning self from each method.
# ---

# %% [markdown]
# # 25. What is the purpose of the __call__ method in Python?
# - The __call__ method makes an object callable like a function.
#
#
# ```python
# class Example:
#     def __call__(self, x):
#         return x * x
#
# obj = Example()
# print(obj(5))  # Output: 25
#
# ```

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# ## `Practical Questions`

# %% [markdown]
# ---
#
#
# ## Question 1: Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# %%
# Parent Class
class Animal:
    def speak(self):
        print("Animal speaks in a generic way.")

# Child Class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Example Usage
animal = Animal()
animal.speak()

dog = Dog()
dog.speak()
# Out:
# Animal speaks in a generic way.
# Bark!

# %% [markdown]
# ---
#
#
# # Question 2: Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod
import math

# Abstract Class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Derived Class Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Derived Class Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example Usage
circle = Circle(5)
print("Area of Circle:", circle.area())

rectangle = Rectangle(4, 6)
print("Area of Rectangle:", rectangle.area())
# Out:
# Area of Circle: 78.53981633974483
# Area of Rectangle: 24

# %% [markdown]
# ---
#
#
# # Question 3: Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# %%
# Base Class
class Vehicle:
    def __init__(self, type):
        self.type = type

# Derived Class
class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

# Further Derived Class
class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

# Example Usage
tesla = ElectricCar("Electric", "Tesla", "100 kWh")
print(f"Type: {tesla.type}, Brand: {tesla.brand}, Battery: {tesla.battery}")
# Out:
# Type: Electric, Brand: Tesla, Battery: 100 kWh

# %% [markdown]
# ---
# # Question 4. Duplicate Question same as question 3

# %% [markdown]
# ---
# # Question 5: Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check_balance.

# %%
class BankAccount:
    def __init__(self, initial_balance):
        self.__balance = initial_balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient funds")

    def check_balance(self):
        return self.__balance

# Example Usage
account = BankAccount(1000)
account.deposit(500)
account.withdraw(200)
print("Current Balance:", account.check_balance())
# Out:
# Current Balance: 1300

# %% [markdown]
# ---
#
#
# # Question 6: Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        print("Playing an instrument")

class Guitar(Instrument):
    def play(self):
        print("Playing Guitar")

class Piano(Instrument):
    def play(self):
        print("Playing Piano")

# Example Usage
instrument = Instrument()
instrument.play()

guitar = Guitar()
guitar.play()

piano = Piano()
piano.play()
# Out:
# Playing an instrument
# Playing Guitar
# Playing Piano

# %% [markdown]
# ---
# # Question 7: Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Example Usage
print("Addition:", MathOperations.add_numbers(5, 3))
print("Subtraction:", MathOperations.subtract_numbers(5, 3))
# Out:
# Addition: 8
# Subtraction: 2

# %% [markdown]
# ---
# # Question 8: Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def get_count(cls):
        return cls.count

# Example Usage
p1 = Person("Alice")
p2 = Person("Bob")
print("Number of Persons Created:", Person.get_count())
# Out:
# Number of Persons Created: 2

# %% [markdown]
# ---
#
#
# # Question 9: Write a class Fraction with attributes numerator and denominator. Override the `__str__` method.

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example Usage
frac = Fraction(3, 4)
print(frac)
# Out:
# 3/4

# %% [markdown]
# ---
# # Question 10: Demonstrate operator overloading by creating a class Vector and overriding the `__add__` method to add two vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

# Example Usage
v1 = Vector(2, 3)
v2 = Vector(4, 5)
result = v1 + v2
print(result)
# Out:
# Vector(6, 8)

# %% [markdown]
# ---
# # Question 11: Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example Usage
person = Person("Alice", 25)
person.greet()
# Out:
# Hello, my name is Alice and I am 25 years old.

# %% [markdown]
# ---
#
# #Question 12 : Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

# Example Usage
student = Student("Bob", [85, 90, 78, 92])
print(f"Average Grade: {student.average_grade()}")
# Out:
# Average Grade: 86.25

# %% [markdown]
# ---
# # Question 13: Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# %%
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example Usage
rect = Rectangle()
rect.set_dimensions(5, 4)
print("Area of Rectangle:", rect.area())
# Out:
# Area of Rectangle: 20

# %% [markdown]
# ---
# # Question 14: Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def __init__(self, hours, rate):
        self.hours = hours
        self.rate = rate

    def calculate_salary(self):
        return self.hours * self.rate

class Manager(Employee):
    def __init__(self, hours, rate, bonus):
        super().__init__(hours, rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# Example Usage
emp = Employee(40, 20)
print("Employee Salary:", emp.calculate_salary())

mgr = Manager(40, 30, 500)
print("Manager Salary:", mgr.calculate_salary())
# Out:
# Employee Salary: 800
# Manager Salary: 1700

# %% [markdown]
# ---
# # Question 15: Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Example Usage
product = Product("Laptop", 1000, 3)
print("Total Price:", product.total_price())
# Out:
# Total Price: 3000

# %% [markdown]
# ---
#
#
# # Question 16: Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo!")

class Sheep(Animal):
    def sound(self):
        print("Baa!")

# Example Usage
cow = Cow()
cow.sound()

sheep = Sheep()
sheep.sound()
# Out:
# Moo!
# Baa!

# %% [markdown]
# ---
#
#
# # Question 17: Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}."

# Example Usage
book = Book("1984", "George Orwell", 1949)
print(book.get_book_info())
# Out:
# '1984' by George Orwell, published in 1949.

# %% [markdown]
# ---
#
#
# # Question 18: Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

# Example Usage
mansion = Mansion("123 Luxury Lane", 5000000, 15)
print(f"Address: {mansion.address}, Price: ${mansion.price}, Rooms: {mansion.number_of_rooms}")
# Out:
# Address: 123 Luxury Lane, Price: $5000000, Rooms: 15

# %% [markdown]
# ---
#
#
#
# ---
